# %% [markdown]
# kadai_005

# %%
# 台形の寸法（cm）
top = 10
bottom = 20
height = 5

# 面積の計算
area = (top + bottom) * height / 2

# 結果の出力（単位cm²）
print(f"{area}cm²")
# Out:
# 75.0cm²

# %% [markdown]
# Kadai List

# %%
# リスト（array）
array = [
    "月曜日は晴れです",
    "火曜日は雨です",
    "水曜日は晴れです",
    "木曜日は晴れです",
    "金曜日は曇りです",
    "土曜日は曇りのち雨です",
    "日曜日は雷雨です"
]

# ディクショナリ（dictionary）
dictionary = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}

# 水曜日の天気（リストから）
print(array[2])

# 水曜日の天気（ディクショナリから）
print(dictionary["wed"])
# Out:
# 水曜日は晴れです
# 晴れ
